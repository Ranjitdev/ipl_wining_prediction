# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
# %matplotlib inline

# %%
raw_data = pd.read_csv('IPL_Matches_2008_2022.csv')
raw_data.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
raw_data.shape
# Out:
# (950, 20)

# %%
raw_data.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %% [markdown]
# ### Season, City, TossWinner, TossDecision, SuperOver, Margin, method, Umpire1, Umpire2 columns are unnecessary for my model

# %%
cls = ['Season', 'City', 'TossWinner', 'TossDecision', 'SuperOver', 'Margin', 'method', 'Umpire1', 'Umpire2']
raw_data.drop(columns=cls, axis=1, inplace=True)

# %% [markdown]
# ### Many teams not playing now ipl so fixing with new data
#     Kings XI Punjab named Punjab Kings
#     Delhi Daredevils named Delhi Capitals
#     Deccan Chargers named Sunrisers Hyderabad
#     Rising Pune Supergiant, Rising Pune Supergiants, Pune Warriors, Gujarat Lions, Kochi Tuskers Kerala dont play matches anymore

# %%
def change_names(obj: str):
    not_playing = [
    'Rising Pune Supergiant', 
    'Rising Pune Supergiants', 
    'Pune Warriors', 
    'Gujarat Lions', 
    'Kochi Tuskers Kerala'
    ]
    if obj in not_playing:
        return np.nan
    elif obj == 'Kings XI Punjab':
        return 'Punjab Kings'
    elif obj == 'Delhi Daredevils':
        return 'Delhi Capitals'
    elif obj == 'Deccan Chargers':
        return 'Sunrisers Hyderabad'
    else:
        return obj

# %%
raw_data['Team1'] = raw_data['Team1'].apply(change_names)
raw_data['Team2'] = raw_data['Team2'].apply(change_names)
raw_data['WinningTeam'] = raw_data['WinningTeam'].apply(change_names)

# %% [markdown]
# ### Filtering and cleaning of data columns
#     1 Date is in date format we dont need so we have to make it year
#     2 winning team and player of the match have some null values in same row
#     3 Team1Players and Team2Players is in list format i have to rectify

# %%
raw_data.dropna(inplace=True, axis=0)

# %% [markdown]
# ### Fixing Date

# %%
for i in range(len(raw_data)):
    raw_data.iloc[i, 1] = raw_data.iloc[i, 1].split('-')[0]
raw_data['Date'] = raw_data['Date'].astype(int)

# %% [markdown]
# ### Fixing and player of the match

# %%
for i in range(len(raw_data)):
    raw_data.iloc[i, 9] = ','.join(eval(raw_data.iloc[i, 9]))

# %%
for i in range(len(raw_data)):
    raw_data.iloc[i, 10] = ','.join(eval(raw_data.iloc[i, 10]))

# %%
raw_data.head()
# Out:
#         ID  Date  MatchNumber                        Team1  \
# 0  1312200  2022        Final             Rajasthan Royals
# 1  1312199  2022  Qualifier 2  Royal Challengers Bangalore
# 2  1312198  2022   Eliminator  Royal Challengers Bangalore
# 3  1312197  2022  Qualifier 1             Rajasthan Royals
# 4  1304116  2022           70          Sunrisers Hyderabad
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 2  Lucknow Super Giants             Eden Gardens, Kolkata
# 3        Gujarat Titans             Eden Gardens, Kolkata
# 4          Punjab Kings          Wankhede Stadium, Mumbai
#
#                    WinningTeam    WonBy Player_of_Match  \
# 0               Gujarat Titans  Wickets       HH Pandya
# 1             Rajasthan Royals  Wickets      JC Buttler
# 2  Royal Challengers Bangalore     Runs      RM Patidar
# 3               Gujarat Titans  Wickets       DA Miller
# 4                 Punjab Kings  Wickets   Harpreet Brar
#
#                                         Team1Players  \
# 0  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...
# 1  V Kohli,F du Plessis,RM Patidar,GJ Maxwell,MK ...
# 2  V Kohli,F du Plessis,RM Patidar,GJ Maxwell,MK ...
# 3  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...
# 4  PK Garg,Abhishek Sharma,RA Tripathi,AK Markram...
#
#                                         Team2Players
# 0  WP Saha,Shubman Gill,MS Wade,HH Pandya,DA Mill...
# 1  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...
# 2  Q de Kock,KL Rahul,M Vohra,DJ Hooda,MP Stoinis...
# 3  WP Saha,Shubman Gill,MS Wade,HH Pandya,DA Mill...
# 4  JM Bairstow,S Dhawan,M Shahrukh Khan,MA Agarwa...

# %%
raw_data.shape
# Out:
# (832, 11)

# %%
raw_data.isna().sum()
# Out:
# ID                 0
# Date               0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# WinningTeam        0
# WonBy              0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# dtype: int64

# %% [markdown]
# ### Ball wise dataset

# %%
raw_data1 = pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
raw_data1.head(2)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
total_run = pd.DataFrame(raw_data1.groupby(['ID', 'innings'], sort=False)['total_run'].sum()).reset_index()
total_run.head(2)
# Out:
#         ID  innings  total_run
# 0  1312200        1        130
# 1  1312200        2        133

# %%
matches = pd.merge(left=raw_data, right=total_run, on='ID')
matches = matches[matches['innings']==1]
matches.drop('innings', axis=1, inplace=True)
matches.head()
# Out:
#         ID  Date  MatchNumber                        Team1  \
# 0  1312200  2022        Final             Rajasthan Royals
# 2  1312199  2022  Qualifier 2  Royal Challengers Bangalore
# 4  1312198  2022   Eliminator  Royal Challengers Bangalore
# 6  1312197  2022  Qualifier 1             Rajasthan Royals
# 8  1304116  2022           70          Sunrisers Hyderabad
#
#                   Team2                             Venue  \
# 0        Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 2      Rajasthan Royals  Narendra Modi Stadium, Ahmedabad
# 4  Lucknow Super Giants             Eden Gardens, Kolkata
# 6        Gujarat Titans             Eden Gardens, Kolkata
# 8          Punjab Kings          Wankhede Stadium, Mumbai
#
#                    WinningTeam    WonBy Player_of_Match  \
# 0               Gujarat Titans  Wickets       HH Pandya
# 2             Rajasthan Royals  Wickets      JC Buttler
# 4  Royal Challengers Bangalore     Runs      RM Patidar
# 6               Gujarat Titans  Wickets       DA Miller
# 8                 Punjab Kings  Wickets   Harpreet Brar
#
#                                         Team1Players  \
# 0  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...
# 2  V Kohli,F du Plessis,RM Patidar,GJ Maxwell,MK ...
# 4  V Kohli,F du Plessis,RM Patidar,GJ Maxwell,MK ...
# 6  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...
# 8  PK Garg,Abhishek Sharma,RA Tripathi,AK Markram...
#
#                                         Team2Players  total_run
# 0  WP Saha,Shubman Gill,MS Wade,HH Pandya,DA Mill...        130
# 2  YBK Jaiswal,JC Buttler,SV Samson,D Padikkal,SO...        157
# 4  Q de Kock,KL Rahul,M Vohra,DJ Hooda,MP Stoinis...        207
# 6  WP Saha,Shubman Gill,MS Wade,HH Pandya,DA Mill...        188
# 8  JM Bairstow,S Dhawan,M Shahrukh Khan,MA Agarwa...        157

# %%
matches = matches[['ID', 'Venue', 'WinningTeam', 'total_run', 'Team1', 'Team2']]
matches.head()
# Out:
#         ID                             Venue                  WinningTeam  \
# 0  1312200  Narendra Modi Stadium, Ahmedabad               Gujarat Titans
# 2  1312199  Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 4  1312198             Eden Gardens, Kolkata  Royal Challengers Bangalore
# 6  1312197             Eden Gardens, Kolkata               Gujarat Titans
# 8  1304116          Wankhede Stadium, Mumbai                 Punjab Kings
#
#    total_run                        Team1                 Team2
# 0        130             Rajasthan Royals        Gujarat Titans
# 2        157  Royal Challengers Bangalore      Rajasthan Royals
# 4        207  Royal Challengers Bangalore  Lucknow Super Giants
# 6        188             Rajasthan Royals        Gujarat Titans
# 8        157          Sunrisers Hyderabad          Punjab Kings

# %%
deliveries = pd.merge(left=matches, right=raw_data1, on='ID')
deliveries.head()
# Out:
#         ID                             Venue     WinningTeam  total_run_x  \
# 0  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 1  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 2  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 3  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 4  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
#
#               Team1           Team2  innings  overs  ballnumber       batter  \
# 0  Rajasthan Royals  Gujarat Titans        1      0           1  YBK Jaiswal
# 1  Rajasthan Royals  Gujarat Titans        1      0           2  YBK Jaiswal
# 2  Rajasthan Royals  Gujarat Titans        1      0           3   JC Buttler
# 3  Rajasthan Royals  Gujarat Titans        1      0           4  YBK Jaiswal
# 4  Rajasthan Royals  Gujarat Titans        1      0           5  YBK Jaiswal
#
#            bowler  non-striker extra_type  batsman_run  extras_run  \
# 0  Mohammed Shami   JC Buttler        NaN            0           0
# 1  Mohammed Shami   JC Buttler    legbyes            0           1
# 2  Mohammed Shami  YBK Jaiswal        NaN            1           0
# 3  Mohammed Shami   JC Buttler        NaN            0           0
# 4  Mohammed Shami   JC Buttler        NaN            0           0
#
#    total_run_y  non_boundary  isWicketDelivery player_out kind  \
# 0            0             0                 0        NaN  NaN
# 1            1             0                 0        NaN  NaN
# 2            1             0                 0        NaN  NaN
# 3            0             0                 0        NaN  NaN
# 4            0             0                 0        NaN  NaN
#
#   fielders_involved       BattingTeam
# 0               NaN  Rajasthan Royals
# 1               NaN  Rajasthan Royals
# 2               NaN  Rajasthan Royals
# 3               NaN  Rajasthan Royals
# 4               NaN  Rajasthan Royals

# %%
deliveries['cur_run'] = deliveries.groupby('ID')['total_run_y'].cumsum()

# %%
deliveries['runs_left'] = (deliveries['total_run_x'] - deliveries['cur_run']) + 1

# %%
deliveries['balls_left'] = 126 - (deliveries['overs']*6 + deliveries['ballnumber'])

# %%
deliveries['player_out'].fillna(0, inplace=True)
deliveries['player_out'] = deliveries['player_out'].apply(lambda x:x if x==0 else 1)
deliveries['player_out'] = deliveries['player_out'].astype(int)

# %%
deliveries['wicket_left'] = 10 - deliveries.groupby('ID')['player_out'].cumsum()

# %%
deliveries['balling_team'] = np.zeros_like(deliveries['BattingTeam'])

# %%
for i in range(len(deliveries)):
    if deliveries.iloc[i, 21] == deliveries.iloc[i, 4]:
        deliveries.iloc[i, 26] = deliveries.iloc[i, 5]
    else:
        deliveries.iloc[i, 26] = deliveries.iloc[i, 4]

# %%
deliveries['crr'] = np.round((deliveries['cur_run']*6)/(126-deliveries['balls_left']), 2)

# %%
deliveries['rrr'] = np.round((deliveries['runs_left']*6)/deliveries['balls_left'], 2)

# %%
def win_or_not(df):
    if df['WinningTeam'] == df['BattingTeam']:
        return 1
    else:
        return 0

# %%
deliveries['win_or_loss'] = deliveries.apply(win_or_not, axis=1)

# %%
deliveries.head()
# Out:
#         ID                             Venue     WinningTeam  total_run_x  \
# 0  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 1  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 2  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 3  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
# 4  1312200  Narendra Modi Stadium, Ahmedabad  Gujarat Titans          130
#
#               Team1           Team2  innings  overs  ballnumber       batter  \
# 0  Rajasthan Royals  Gujarat Titans        1      0           1  YBK Jaiswal
# 1  Rajasthan Royals  Gujarat Titans        1      0           2  YBK Jaiswal
# 2  Rajasthan Royals  Gujarat Titans        1      0           3   JC Buttler
# 3  Rajasthan Royals  Gujarat Titans        1      0           4  YBK Jaiswal
# 4  Rajasthan Royals  Gujarat Titans        1      0           5  YBK Jaiswal
#
#            bowler  non-striker extra_type  batsman_run  extras_run  \
# 0  Mohammed Shami   JC Buttler        NaN            0           0
# 1  Mohammed Shami   JC Buttler    legbyes            0           1
# 2  Mohammed Shami  YBK Jaiswal        NaN            1           0
# 3  Mohammed Shami   JC Buttler        NaN            0           0
# 4  Mohammed Shami   JC Buttler        NaN            0           0
#
#    total_run_y  non_boundary  isWicketDelivery  player_out kind  \
# 0            0             0                 0           0  NaN
# 1            1             0                 0           0  NaN
# 2            1             0                 0           0  NaN
# 3            0             0                 0           0  NaN
# 4            0             0                 0           0  NaN
#
#   fielders_involved       BattingTeam  cur_run  runs_left  balls_left  \
# 0               NaN  Rajasthan Royals        0        131         125
# 1               NaN  Rajasthan Royals        1        130         124
# 2               NaN  Rajasthan Royals        2        129         123
# 3               NaN  Rajasthan Royals        2        129         122
# 4               NaN  Rajasthan Royals        2        129         121
#
#    wicket_left    balling_team  crr   rrr  win_or_loss
# 0           10  Gujarat Titans  0.0  6.29            0
# 1           10  Gujarat Titans  3.0  6.29            0
# 2           10  Gujarat Titans  4.0  6.29            0
# 3           10  Gujarat Titans  3.0  6.34            0
# 4           10  Gujarat Titans  2.4  6.40            0

# %%
final_data = deliveries[[
    'BattingTeam', 'balling_team', 'Venue', 'runs_left', 'balls_left', 'wicket_left', 'total_run_x', 'crr', 'rrr', 'win_or_loss'
]]
final_data.columns = [
    'Batting', 'Bowling', 'Venue', 'Runs_left', 'Balls_left', 'Wicket_left', 'Total_run', 'crr', 'rrr', 'Result'
]
final_data.head()
# Out:
#             Batting         Bowling                             Venue  \
# 0  Rajasthan Royals  Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 1  Rajasthan Royals  Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 2  Rajasthan Royals  Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 3  Rajasthan Royals  Gujarat Titans  Narendra Modi Stadium, Ahmedabad
# 4  Rajasthan Royals  Gujarat Titans  Narendra Modi Stadium, Ahmedabad
#
#    Runs_left  Balls_left  Wicket_left  Total_run  crr   rrr  Result
# 0        131         125           10        130  0.0  6.29       0
# 1        130         124           10        130  3.0  6.29       0
# 2        129         123           10        130  4.0  6.29       0
# 3        129         122           10        130  3.0  6.34       0
# 4        129         121           10        130  2.4  6.40       0

# %%
final_data.to_csv('data.csv', index=False, header=True)

# %%
final_data.shape
# Out:
# (198626, 10)

# %%
final_data.isna().sum()
# Out:
# Batting        0
# Bowling        0
# Venue          0
# Runs_left      0
# Balls_left     0
# Wicket_left    0
# Total_run      0
# crr            0
# rrr            0
# Result         0
# dtype: int64
